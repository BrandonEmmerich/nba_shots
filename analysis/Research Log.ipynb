# %% [markdown]
# # 20190607
#
# -----
#
# Initial exploration of the NBA shot data

# %%
import itertools as it
import json
import numpy as np
import pandas as pd

# %%
with open('../data/all_shot_data.json') as json_file:  
    data = json.load(json_file)
    
df_raw = pd.DataFrame(list(it.chain.from_iterable([player['shots'] for player in data['data']])))
df_raw.head()
# Out:
#             ACTION_TYPE   EVENT_TYPE GAME_DATE  GAME_EVENT_ID     GAME_ID  \
# 0             Dunk Shot    Made Shot  20181017             28  0021800006
# 1    Driving Layup Shot  Missed Shot  20181017             66  0021800006
# 2             Jump Shot    Made Shot  20181017            164  0021800006
# 3  Turnaround Jump Shot    Made Shot  20181017            224  0021800006
# 4  Turnaround Jump Shot  Missed Shot  20181017            238  0021800006
#
#            GRID_TYPE  HTM  LOC_X  LOC_Y  MINUTES_REMAINING  ...  \
# 0  Shot Chart Detail  ORL      0      3                  9  ...
# 1  Shot Chart Detail  ORL    -20     27                  7  ...
# 2  Shot Chart Detail  ORL   -225     11                  0  ...
# 3  Shot Chart Detail  ORL     51    155                  8  ...
# 4  Shot Chart Detail  ORL    -91     87                  7  ...
#
#    SHOT_ATTEMPTED_FLAG  SHOT_DISTANCE SHOT_MADE_FLAG       SHOT_TYPE  \
# 0                    1              0              1  2PT Field Goal
# 1                    1              3              0  2PT Field Goal
# 2                    1             22              1  3PT Field Goal
# 3                    1             16              1  2PT Field Goal
# 4                    1             12              0  2PT Field Goal
#
#           SHOT_ZONE_AREA  SHOT_ZONE_BASIC  SHOT_ZONE_RANGE     TEAM_ID  \
# 0              Center(C)  Restricted Area  Less Than 8 ft.  1610612753
# 1              Center(C)  Restricted Area  Less Than 8 ft.  1610612753
# 2           Left Side(L)    Left Corner 3          24+ ft.  1610612753
# 3  Right Side Center(RC)        Mid-Range        16-24 ft.  1610612753
# 4           Left Side(L)        Mid-Range         8-16 ft.  1610612753
#
#        TEAM_NAME  VTM
# 0  Orlando Magic  MIA
# 1  Orlando Magic  MIA
# 2  Orlando Magic  MIA
# 3  Orlando Magic  MIA
# 4  Orlando Magic  MIA
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Understand the Data
# What are the possible values of each field? Let's find a player with lots of shots, use them as a sample, and figure out what all the fields mean.

# %%
df_raw\
    .groupby(['PLAYER_ID', 'PLAYER_NAME'])\
    .agg({'SHOT_MADE_FLAG': 'count'})\
    .sort_values(by=['SHOT_MADE_FLAG'], ascending=False)\
    .head()
# Out:
#                           SHOT_MADE_FLAG
# PLAYER_ID PLAYER_NAME
# 201935    James Harden              1909
# 202689    Kemba Walker              1684
# 202331    Paul George               1614
# 203078    Bradley Beal              1609
# 203081    Damian Lillard            1533

# %%
harden = df_raw[df_raw['PLAYER_ID'] == 201935]

# %%
harden.columns
# Out:
# Index(['ACTION_TYPE', 'EVENT_TYPE', 'GAME_DATE', 'GAME_EVENT_ID', 'GAME_ID',
#        'GRID_TYPE', 'HTM', 'LOC_X', 'LOC_Y', 'MINUTES_REMAINING', 'PERIOD',
#        'PLAYER_ID', 'PLAYER_NAME', 'SECONDS_REMAINING', 'SHOT_ATTEMPTED_FLAG',
#        'SHOT_DISTANCE', 'SHOT_MADE_FLAG', 'SHOT_TYPE', 'SHOT_ZONE_AREA',
#        'SHOT_ZONE_BASIC', 'SHOT_ZONE_RANGE', 'TEAM_ID', 'TEAM_NAME', 'VTM'],
#       dtype='object')

# %%
harden\
    .groupby(['ACTION_TYPE'])\
    .agg({'SHOT_MADE_FLAG': 'count'})\
    .sort_values(by='SHOT_MADE_FLAG', ascending=False)

## It seems like we might want to simplify these. Like, we might group these into bigger categories: drive, shot, etc.
# Out:
#                                     SHOT_MADE_FLAG
# ACTION_TYPE
# Step Back Jump shot                            587
# Jump Shot                                      349
# Driving Layup Shot                             324
# Driving Floating Jump Shot                     170
# Pullup Jump shot                               150
# Driving Finger Roll Layup Shot                  79
# Layup Shot                                      58
# Running Layup Shot                              37
# Floating Jump shot                              28
# Driving Floating Bank Jump Shot                 27
# Fadeaway Jump Shot                              14
# Driving Dunk Shot                               11
# Driving Reverse Layup Shot                       9
# Cutting Layup Shot                               9
# Turnaround Fadeaway shot                         7
# Running Finger Roll Layup Shot                   7
# Running Dunk Shot                                6
# Cutting Dunk Shot                                5
# Reverse Layup Shot                               4
# Driving Hook Shot                                4
# Running Jump Shot                                3
# Hook Shot                                        3
# Running Pull-Up Jump Shot                        3
# Tip Layup Shot                                   3
# Turnaround Jump Shot                             3
# Jump Bank Shot                                   2
# Step Back Bank Jump Shot                         2
# Turnaround Fadeaway Bank Jump Shot               2
# Putback Layup Shot                               1
# Cutting Finger Roll Layup Shot                   1
# Finger Roll Layup Shot                           1

# %%
harden\
    .groupby(['EVENT_TYPE'])\
    .agg({'SHOT_MADE_FLAG': 'count'})\
    .sort_values(by='SHOT_MADE_FLAG', ascending=False)
# Out:
#              SHOT_MADE_FLAG
# EVENT_TYPE
# Missed Shot            1066
# Made Shot               843

# %%
harden\
    .groupby(['GRID_TYPE'])\
    .agg({'SHOT_MADE_FLAG': 'count'})\
    .sort_values(by='SHOT_MADE_FLAG', ascending=False)
# Out:
#                    SHOT_MADE_FLAG
# GRID_TYPE
# Shot Chart Detail            1909

# %%
harden\
    .groupby(['LOC_Y'])\
    .agg({'SHOT_MADE_FLAG': 'count'})\
    .sort_values(by='SHOT_MADE_FLAG', ascending=False)

harden['LOC_Y'].min()

# I think that LOC_X and LOC_Y might be position on the court. But, I'm not sure. Might want to find a relationship between them and the shot distance parameter.
# Out:
# -32

# %%
harden\
    .groupby(['SHOT_DISTANCE'])\
    .agg({'SHOT_MADE_FLAG': 'count'})\
    .sort_values(by='SHOT_MADE_FLAG', ascending=False)
# Out:
#                SHOT_MADE_FLAG
# SHOT_DISTANCE
# 25                        292
# 26                        277
# 1                         216
# 2                         145
# 27                        137
# 24                        120
# 0                          89
# 3                          69
# 4                          61
# 28                         60
# 5                          56
# 23                         53
# 6                          45
# 7                          33
# 29                         32
# 8                          28
# 22                         26
# 9                          23
# 11                         22
# 10                         20
# 12                         13
# 30                         12
# 15                         10
# 13                         10
# 17                          9
# 31                          9
# 19                          7
# 20                          7
# 14                          6
# 32                          5
# 16                          4
# 21                          3
# 18                          3
# 34                          2
# 35                          2
# 33                          1
# 40                          1
# 48                          1

# %%
harden\
    .groupby(['SHOT_TYPE'])\
    .agg({'SHOT_MADE_FLAG': 'count'})\
    .sort_values(by='SHOT_MADE_FLAG', ascending=False)
# Out:
#                 SHOT_MADE_FLAG
# SHOT_TYPE
# 3PT Field Goal            1028
# 2PT Field Goal             881

# %%
harden\
    .groupby(['SHOT_ZONE_AREA'])\
    .agg({'SHOT_MADE_FLAG': 'count'})\
    .sort_values(by='SHOT_MADE_FLAG', ascending=False)
# Out:
#                        SHOT_MADE_FLAG
# SHOT_ZONE_AREA
# Center(C)                        1094
# Right Side Center(RC)             377
# Left Side Center(LC)              289
# Right Side(R)                      76
# Left Side(L)                       72
# Back Court(BC)                      1

# %%
harden\
    .groupby(['SHOT_ZONE_BASIC'])\
    .agg({'SHOT_MADE_FLAG': 'count'})\
    .sort_values(by='SHOT_MADE_FLAG', ascending=False)
# Out:
#                        SHOT_MADE_FLAG
# SHOT_ZONE_BASIC
# Above the Break 3                 942
# Restricted Area                   519
# In The Paint (Non-RA)             281
# Mid-Range                          81
# Right Corner 3                     50
# Left Corner 3                      35
# Backcourt                           1

# %%
harden\
    .groupby(['SHOT_ZONE_RANGE'])\
    .agg({'SHOT_MADE_FLAG': 'count'})\
    .sort_values(by='SHOT_MADE_FLAG', ascending=False)
# Out:
#                  SHOT_MADE_FLAG
# SHOT_ZONE_RANGE
# 24+ ft.                    1027
# Less Than 8 ft.             714
# 8-16 ft.                    132
# 16-24 ft.                    35
# Back Court Shot               1

# %% [markdown]
# **NOTES:** OK, it seems like we have a real trove of data here where we can get shooting percentages by shot type. Remember, the goal here is to develop a metric to tracks how many quality shots a team gets. I'm noticing now that I'm not seeing a field that shows how open the player is... Let me check in on the data source for that. That is important for us.

# %% [markdown]
# OK, so, this is a bummer. The closest defender range data is gone. So, that means that whatever we do here, we won't have access to that. (Online consensus seems to be that somebody now is selling the data rather than the NBA just expopsing it for free). Can we still look into luck and the basketball meta-game without defender data?

# %%
df_raw\
    .groupby(['ACTION_TYPE'])\
    .agg({'SHOT_MADE_FLAG': 'count'})\
    .sort_values(by='SHOT_MADE_FLAG', ascending=False)

# Let's group by the following: Layup, Jump Shot, Pullup Jump Shot, Step Back Jump Shot, Other Jump Shot, Driving Layup, DUNK
# Out:
#                                     SHOT_MADE_FLAG
# ACTION_TYPE
# Jump Shot                                    77517
# Pullup Jump shot                             23959
# Driving Layup Shot                           20340
# Layup Shot                                   11404
# Step Back Jump shot                           7878
# Driving Floating Jump Shot                    7327
# Cutting Layup Shot                            5286
# Tip Layup Shot                                4884
# Floating Jump shot                            4880
# Running Layup Shot                            4668
# Driving Finger Roll Layup Shot                4168
# Hook Shot                                     3664
# Fadeaway Jump Shot                            3611
# Turnaround Jump Shot                          3287
# Cutting Dunk Shot                             3227
# Turnaround Hook Shot                          2752
# Putback Layup Shot                            2745
# Turnaround Fadeaway shot                      2546
# Dunk Shot                                     2362
# Driving Floating Bank Jump Shot               2343
# Driving Reverse Layup Shot                    2203
# Driving Dunk Shot                             1950
# Alley Oop Dunk Shot                           1863
# Reverse Layup Shot                            1758
# Running Dunk Shot                             1722
# Driving Hook Shot                             1447
# Running Jump Shot                             1398
# Alley Oop Layup shot                          1090
# Running Pull-Up Jump Shot                     1016
# Jump Bank Shot                                 943
# Running Finger Roll Layup Shot                 819
# Tip Dunk Shot                                  762
# Cutting Finger Roll Layup Shot                 640
# Turnaround Fadeaway Bank Jump Shot             581
# Putback Dunk Shot                              525
# Finger Roll Layup Shot                         519
# Running Reverse Layup Shot                     339
# Turnaround Bank Hook Shot                      229
# Hook Bank Shot                                 195
# Driving Bank Hook Shot                         165
# Running Alley Oop Dunk Shot                    135
# Reverse Dunk Shot                              120
# Running Alley Oop Layup Shot                    69
# Step Back Bank Jump Shot                        53
# Driving Reverse Dunk Shot                       49
# Running Reverse Dunk Shot                       20

# %%
conditions_action = [
    (df_raw['ACTION_TYPE'] == 'Pullup Jump shot'),
    (df_raw['ACTION_TYPE'] == 'Step Back Jump shot'),
    (df_raw['ACTION_TYPE'] == 'Driving Layup Shot'),
    (df_raw['ACTION_TYPE'].str.contains('Layup')),
    (df_raw['ACTION_TYPE'].str.contains('Jump')),
    (df_raw['ACTION_TYPE'].str.contains('Dunk')),
]

choices_action = ['Pullup Jump Shot', 'Step Back Jump Shot', 'Driving Layup Shot', 'Layup', 'Other Jump Shot', 'Dunk']

conditions_value = [
    (df_raw['SHOT_TYPE'] == '3PT Field Goal')
]

choices_value = [3]

def clean_threes(x):
    if 'Corner' in x:
        return 'Corner Three'
    else:
        return x

df = df_raw\
    .assign(
        action_type_clean= np.select(conditions_action, choices_action, default='Other'),
        shot_value = np.select(conditions_value, choices_value, default = 2),
        shot_zone = lambda x: x['SHOT_ZONE_BASIC'].apply(clean_threes))

df.reset_index(level=0, inplace=True)

df.head()
# Out:
#    index           ACTION_TYPE   EVENT_TYPE GAME_DATE  GAME_EVENT_ID  \
# 0      0             Dunk Shot    Made Shot  20181017             28
# 1      1    Driving Layup Shot  Missed Shot  20181017             66
# 2      2             Jump Shot    Made Shot  20181017            164
# 3      3  Turnaround Jump Shot    Made Shot  20181017            224
# 4      4  Turnaround Jump Shot  Missed Shot  20181017            238
#
#       GAME_ID          GRID_TYPE  HTM  LOC_X  LOC_Y  ...       SHOT_TYPE  \
# 0  0021800006  Shot Chart Detail  ORL      0      3  ...  2PT Field Goal
# 1  0021800006  Shot Chart Detail  ORL    -20     27  ...  2PT Field Goal
# 2  0021800006  Shot Chart Detail  ORL   -225     11  ...  3PT Field Goal
# 3  0021800006  Shot Chart Detail  ORL     51    155  ...  2PT Field Goal
# 4  0021800006  Shot Chart Detail  ORL    -91     87  ...  2PT Field Goal
#
#           SHOT_ZONE_AREA  SHOT_ZONE_BASIC  SHOT_ZONE_RANGE     TEAM_ID  \
# 0              Center(C)  Restricted Area  Less Than 8 ft.  1610612753
# 1              Center(C)  Restricted Area  Less Than 8 ft.  1610612753
# 2           Left Side(L)    Left Corner 3          24+ ft.  1610612753
# 3  Right Side Center(RC)        Mid-Range        16-24 ft.  1610612753
# 4           Left Side(L)        Mid-Range         8-16 ft.  1610612753
#
#        TEAM_NAME  VTM   action_type_clean shot_value        shot_zone
# 0  Orlando Magic  MIA                Dunk          2  Restricted Area
# 1  Orlando Magic  MIA  Driving Layup Shot          2  Restricted Area
# 2  Orlando Magic  MIA     Other Jump Shot          3     Corner Three
# 3  Orlando Magic  MIA     Other Jump Shot          2        Mid-Range
# 4  Orlando Magic  MIA     Other Jump Shot          2        Mid-Range
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Analysis
# What is the leage average by shot type and zone? What is the distribution of each? For each player can we give them a score which is like the total points above expectation based on that zone?

# %%
results = df\
    .groupby(['action_type_clean', 'shot_zone', 'shot_value'])\
    .agg({'SHOT_MADE_FLAG': ['mean', 'count']})\
    .reset_index()

results.columns = ['shot_type', 'shot_zone', 'shot_value', 'league_average', 'frequency']

results\
    .assign(expected_value=lambda x: x['league_average'] * x['shot_value'])\
    .sort_values(by=['expected_value'], ascending=False)
# Out:
#               shot_type              shot_zone  shot_value  league_average  \
# 4                  Dunk              Mid-Range           2        1.000000
# 28     Pullup Jump Shot              Mid-Range           3        0.600000
# 5                  Dunk        Restricted Area           2        0.898484
# 25     Pullup Jump Shot           Corner Three           3        0.476331
# 8                 Layup        Restricted Area           2        0.606739
# 20      Other Jump Shot              Mid-Range           3        0.400000
# 31  Step Back Jump Shot      Above the Break 3           3        0.388802
# 17      Other Jump Shot           Corner Three           3        0.380583
# 32  Step Back Jump Shot           Corner Three           3        0.373228
# 23     Pullup Jump Shot      Above the Break 3           3        0.363399
# 13                Other        Restricted Area           2        0.532106
# 3                  Dunk  In The Paint (Non-RA)           2        0.526718
# 2    Driving Layup Shot        Restricted Area           2        0.518521
# 15      Other Jump Shot      Above the Break 3           3        0.344504
# 21      Other Jump Shot        Restricted Area           2        0.489190
# 11                Other  In The Paint (Non-RA)           2        0.462296
# 33  Step Back Jump Shot  In The Paint (Non-RA)           2        0.450467
# 26     Pullup Jump Shot  In The Paint (Non-RA)           2        0.449476
# 34  Step Back Jump Shot              Mid-Range           2        0.431525
# 27     Pullup Jump Shot              Mid-Range           2        0.430426
# 12                Other              Mid-Range           2        0.414327
# 18      Other Jump Shot  In The Paint (Non-RA)           2        0.412443
# 29     Pullup Jump Shot        Restricted Area           2        0.410526
# 19      Other Jump Shot              Mid-Range           2        0.376479
# 22     Pullup Jump Shot      Above the Break 3           2        0.333333
# 6                 Layup  In The Paint (Non-RA)           2        0.317551
# 7                 Layup              Mid-Range           2        0.311111
# 35  Step Back Jump Shot              Mid-Range           3        0.166667
# 0    Driving Layup Shot  In The Paint (Non-RA)           2        0.231177
# 10                Other           Corner Three           3        0.142857
# 24     Pullup Jump Shot              Backcourt           3        0.122807
# 1    Driving Layup Shot              Mid-Range           2        0.140845
# 9                 Other      Above the Break 3           3        0.058824
# 16      Other Jump Shot              Backcourt           3        0.017115
# 30  Step Back Jump Shot      Above the Break 3           2        0.000000
# 14      Other Jump Shot      Above the Break 3           2        0.000000
# 36  Step Back Jump Shot        Restricted Area           2        0.000000
#
#     frequency  expected_value
# 4           5        2.000000
# 28          5        1.800000
# 5       12599        1.796968
# 25        338        1.428994
# 8       37334        1.213478
# 20        115        1.200000
# 31       3215        1.166407
# 17      16903        1.141750
# 32        635        1.119685
# 23       8426        1.090197
# 13       2227        1.064212
# 3         131        1.053435
# 2       17440        1.037041
# 15      48609        1.033512
# 21       2729        0.978380
# 11       7002        0.924593
# 33        535        0.900935
# 26       3246        0.898953
# 34       3483        0.863049
# 27      11786        0.860852
# 12       1745        0.828653
# 18      18211        0.824886
# 29         95        0.821053
# 19      15969        0.752959
# 22          6        0.666667
# 6        3168        0.635101
# 7          90        0.622222
# 35          6        0.500000
# 0        2829        0.462354
# 10          7        0.428571
# 24         57        0.368421
# 1          71        0.281690
# 9          17        0.176471
# 16        409        0.051345
# 30          1        0.000000
# 14         11        0.000000
# 36          3        0.000000

# %% [markdown]
# **Some Ideas:** What if we calculated expected value for each shot then used that to join on the raw data to get total and average points over expectation for each player in the league. Use that as a measure of shooting ability.
#
# Then, we can go game by game and compare relative points over expected and relative expected points and see why each team won each game - ie, they got better shots than the other team, or, they made more shots than the other team.
#
# Also, I can do quality share of shots for each game to see who is getting good looks

# %% [markdown]
# # 20190609
#
# Let's assign an expected value for each shot and for each player let's total up total points, total expected points, the delta between the two, and averages

# %%
results = df\
    .groupby(['action_type_clean', 'shot_zone', 'shot_value'])\
    .agg({'SHOT_MADE_FLAG': ['mean', 'count']})\
    .reset_index()

results.columns = ['action_type_clean', 'shot_zone', 'shot_value', 'league_average', 'frequency']

results = results\
    .assign(
        expected_value=lambda x: x['league_average'] * x['shot_value']
    )\
    .sort_values(by=['expected_value'], ascending=False)

# %%
df.columns
# Out:
# Index(['ACTION_TYPE', 'EVENT_TYPE', 'GAME_DATE', 'GAME_EVENT_ID', 'GAME_ID',
#        'GRID_TYPE', 'HTM', 'LOC_X', 'LOC_Y', 'MINUTES_REMAINING', 'PERIOD',
#        'PLAYER_ID', 'PLAYER_NAME', 'SECONDS_REMAINING', 'SHOT_ATTEMPTED_FLAG',
#        'SHOT_DISTANCE', 'SHOT_MADE_FLAG', 'SHOT_TYPE', 'SHOT_ZONE_AREA',
#        'SHOT_ZONE_BASIC', 'SHOT_ZONE_RANGE', 'TEAM_ID', 'TEAM_NAME', 'VTM',
#        'action_type_clean', 'shot_value', 'shot_zone'],
#       dtype='object')

# %%
player_aggregates = df[['PLAYER_NAME', 'shot_value', 'shot_zone', 'action_type_clean', 'SHOT_MADE_FLAG']]\
    .merge(results, how='left', on=['shot_zone', 'action_type_clean'])\
    .assign(
        points = lambda x: x['SHOT_MADE_FLAG'] * x['shot_value_y'],
        points_above_expectation = lambda x: x['points'] - x['expected_value']
    )\
    .groupby(['PLAYER_NAME'])\
    .agg({
        'expected_value': ['mean','sum', 'count'],
        'points': ['mean','sum', 'count'],
        'points_above_expectation': ['mean','sum', 'count'],    
    })\
    .reset_index()

player_aggregates.columns = ['player_name', 
                            'expected_value_mean', 'expected_value_sum', 'expected_value_count',
                            'points_mean', 'points_sum', 'points_count',
                            'points_above_expectation_mean', 'points_above_expectation_sum', 'points_above_expectation_count']

player_aggregates\
    .sort_values(by = ['points_above_expectation_sum'], ascending=False)\
    .drop(['expected_value_count', 'points_above_expectation_count', 'points_count'], axis = 1)\
    .head()
# Out:
#        player_name  expected_value_mean  expected_value_sum  points_mean  \
# 451  Stephen Curry             0.762223         1668.506704     1.108725
# 224   James Harden             0.738551         2160.260926     0.974359
# 54     Buddy Hield             0.819023         1762.537309     1.071097
# 302   Kevin Durant             0.928549         1990.810094     1.173974
# 310  Klay Thompson             0.853897         1952.007515     1.082677
#
#      points_sum  points_above_expectation_mean  points_above_expectation_sum
# 451        2427                       0.346502                    758.493296
# 224        2850                       0.235808                    689.739074
# 54         2305                       0.252074                    542.462691
# 302        2517                       0.245424                    526.189906
# 310        2475                       0.228781                    522.992485

# %% [markdown]
# ## How Does Steph Get His Buckets?

# %%
steph = df[['PLAYER_NAME', 'shot_value', 'shot_zone', 'action_type_clean', 'SHOT_MADE_FLAG']]\
    .query('PLAYER_NAME == "Stephen Curry"')\
    .assign(
        points = lambda x: x['SHOT_MADE_FLAG'] * x['shot_value'],
    )\
    .groupby(['action_type_clean', 'shot_zone', 'shot_value'])\
    .agg({'SHOT_MADE_FLAG': ['mean', 'count']})\
    .reset_index()

steph.columns = ['action_type_clean', 'shot_zone', 'shot_value', 'shooting_percentage', 'frequency']

steph\
    .assign(
        expected_value=lambda x: x['shooting_percentage'] * x['shot_value']
    )\
    .merge(results, how='left', on = ['action_type_clean', 'shot_zone'])\
    [['action_type_clean', 'shot_zone', 'shot_value_x', 'shooting_percentage', 'league_average', 'frequency_x']]

# \
#     .groupby(['PLAYER_NAME'])\
#     .agg({
#         'expected_value': ['mean','sum', 'count'],
#         'points': ['mean','sum', 'count'],
#         'points_above_expectation': ['mean','sum', 'count'],    
#     })\
#     .groupby(['action_type_clean', 'shot_zone', 'shot_value'])\
#     .agg({'SHOT_MADE_FLAG': ['mean', 'count']})\
#     .reset_index()
# Out:
#       action_type_clean              shot_zone  shot_value_x  \
# 0    Driving Layup Shot  In The Paint (Non-RA)             2
# 1    Driving Layup Shot              Mid-Range             2
# 2    Driving Layup Shot        Restricted Area             2
# 3                  Dunk        Restricted Area             2
# 4                 Layup  In The Paint (Non-RA)             2
# 5                 Layup              Mid-Range             2
# 6                 Layup        Restricted Area             2
# 7                 Other           Corner Three             3
# 8                 Other  In The Paint (Non-RA)             2
# 9                 Other              Mid-Range             2
# 10                Other        Restricted Area             2
# 11      Other Jump Shot      Above the Break 3             3
# 12      Other Jump Shot      Above the Break 3             3
# 13      Other Jump Shot              Backcourt             3
# 14      Other Jump Shot           Corner Three             3
# 15      Other Jump Shot  In The Paint (Non-RA)             2
# 16      Other Jump Shot              Mid-Range             2
# 17      Other Jump Shot              Mid-Range             2
# 18      Other Jump Shot        Restricted Area             2
# 19     Pullup Jump Shot      Above the Break 3             3
# 20     Pullup Jump Shot      Above the Break 3             3
# 21     Pullup Jump Shot              Backcourt             3
# 22     Pullup Jump Shot           Corner Three             3
# 23     Pullup Jump Shot  In The Paint (Non-RA)             2
# 24     Pullup Jump Shot              Mid-Range             2
# 25     Pullup Jump Shot              Mid-Range             2
# 26  Step Back Jump Shot      Above the Break 3             3
# 27  Step Back Jump Shot      Above the Break 3             3
# 28  Step Back Jump Shot           Corner Three             3
# 29  Step Back Jump Shot  In The Paint (Non-RA)             2
# 30  Step Back Jump Shot              Mid-Range             2
# 31  Step Back Jump Shot              Mid-Range             2
#
#     shooting_percentage  league_average  frequency_x
# 0              0.200000        0.231177           10
# 1              1.000000        0.140845            1
# 2              0.607843        0.518521           51
# 3              0.333333        0.898484            3
# 4              0.566667        0.317551           30
# 5              0.500000        0.311111            6
# 6              0.649425        0.606739          174
# 7              0.500000        0.142857            2
# 8              0.250000        0.462296            4
# 9              0.333333        0.414327            6
# 10             0.000000        0.532106            2
# 11             0.354906        0.344504          479
# 12             0.354906        0.000000          479
# 13             0.000000        0.017115            9
# 14             0.482143        0.380583          112
# 15             0.490566        0.412443           53
# 16             0.347368        0.400000           95
# 17             0.347368        0.376479           95
# 18             0.500000        0.489190            4
# 19             0.611111        0.363399          126
# 20             0.611111        0.333333          126
# 21             0.500000        0.122807            2
# 22             0.833333        0.476331           12
# 23             0.000000        0.449476            2
# 24             0.604167        0.600000           48
# 25             0.604167        0.430426           48
# 26             0.639344        0.388802           61
# 27             0.639344        0.000000           61
# 28             0.285714        0.373228            7
# 29             0.000000        0.450467            1
# 30             0.425000        0.431525           40
# 31             0.425000        0.166667           40

# %%
results.shape
# Out:
# (37, 6)

# %%
steph.shape
# Out:
# (26, 5)

# %%
results.query('shot_zone == "Mid-Range" and action_type_clean == "Step Back Jump Shot"')
# Out:
#       action_type_clean  shot_zone  shot_value  league_average  frequency  \
# 34  Step Back Jump Shot  Mid-Range           2        0.431525       3483
# 35  Step Back Jump Shot  Mid-Range           3        0.166667          6
#
#     expected_value
# 34        0.863049
# 35        0.500000

# %%
results.sort_values(by = ['action_type_clean', 'shot_zone'])
# Out:
#       action_type_clean              shot_zone  shot_value  league_average  \
# 0    Driving Layup Shot  In The Paint (Non-RA)           2        0.231177
# 1    Driving Layup Shot              Mid-Range           2        0.140845
# 2    Driving Layup Shot        Restricted Area           2        0.518521
# 3                  Dunk  In The Paint (Non-RA)           2        0.526718
# 4                  Dunk              Mid-Range           2        1.000000
# 5                  Dunk        Restricted Area           2        0.898484
# 6                 Layup  In The Paint (Non-RA)           2        0.317551
# 7                 Layup              Mid-Range           2        0.311111
# 8                 Layup        Restricted Area           2        0.606739
# 9                 Other      Above the Break 3           3        0.058824
# 10                Other           Corner Three           3        0.142857
# 11                Other  In The Paint (Non-RA)           2        0.462296
# 12                Other              Mid-Range           2        0.414327
# 13                Other        Restricted Area           2        0.532106
# 15      Other Jump Shot      Above the Break 3           3        0.344504
# 14      Other Jump Shot      Above the Break 3           2        0.000000
# 16      Other Jump Shot              Backcourt           3        0.017115
# 17      Other Jump Shot           Corner Three           3        0.380583
# 18      Other Jump Shot  In The Paint (Non-RA)           2        0.412443
# 20      Other Jump Shot              Mid-Range           3        0.400000
# 19      Other Jump Shot              Mid-Range           2        0.376479
# 21      Other Jump Shot        Restricted Area           2        0.489190
# 23     Pullup Jump Shot      Above the Break 3           3        0.363399
# 22     Pullup Jump Shot      Above the Break 3           2        0.333333
# 24     Pullup Jump Shot              Backcourt           3        0.122807
# 25     Pullup Jump Shot           Corner Three           3        0.476331
# 26     Pullup Jump Shot  In The Paint (Non-RA)           2        0.449476
# 28     Pullup Jump Shot              Mid-Range           3        0.600000
# 27     Pullup Jump Shot              Mid-Range           2        0.430426
# 29     Pullup Jump Shot        Restricted Area           2        0.410526
# 31  Step Back Jump Shot      Above the Break 3           3        0.388802
# 30  Step Back Jump Shot      Above the Break 3           2        0.000000
# 32  Step Back Jump Shot           Corner Three           3        0.373228
# 33  Step Back Jump Shot  In The Paint (Non-RA)           2        0.450467
# 34  Step Back Jump Shot              Mid-Range           2        0.431525
# 35  Step Back Jump Shot              Mid-Range           3        0.166667
# 36  Step Back Jump Shot        Restricted Area           2        0.000000
#
#     frequency  expected_value
# 0        2829        0.462354
# 1          71        0.281690
# 2       17440        1.037041
# 3         131        1.053435
# 4           5        2.000000
# 5       12599        1.796968
# 6        3168        0.635101
# 7          90        0.622222
# 8       37334        1.213478
# 9          17        0.176471
# 10          7        0.428571
# 11       7002        0.924593
# 12       1745        0.828653
# 13       2227        1.064212
# 15      48609        1.033512
# 14         11        0.000000
# 16        409        0.051345
# 17      16903        1.141750
# 18      18211        0.824886
# 20        115        1.200000
# 19      15969        0.752959
# 21       2729        0.978380
# 23       8426        1.090197
# 22          6        0.666667
# 24         57        0.368421
# 25        338        1.428994
# 26       3246        0.898953
# 28          5        1.800000
# 27      11786        0.860852
# 29         95        0.821053
# 31       3215        1.166407
# 30          1        0.000000
# 32        635        1.119685
# 33        535        0.900935
# 34       3483        0.863049
# 35          6        0.500000
# 36          3        0.000000

# %% [markdown]
# We need t clean out some of these shots that are classified as mid range but have a shot value of three. That is not making any sense

# %% [markdown]
# # 20190615

# %%
with open('../data/all_shot_data.json') as json_file:  
    data = json.load(json_file)
    
df_raw = pd.DataFrame(list(it.chain.from_iterable([player['shots'] for player in data['data']])))

# %%
def clean_threes(x):
    if 'Corner' in x:
        return 'Corner Three'
    else:
        return x
    
conditions_action = [
    (df_raw['ACTION_TYPE'] == 'Pullup Jump shot'),
    (df_raw['ACTION_TYPE'] == 'Step Back Jump shot'),
    (df_raw['ACTION_TYPE'] == 'Driving Layup Shot'),
    (df_raw['ACTION_TYPE'].str.contains('Layup')),
    (df_raw['ACTION_TYPE'].str.contains('Jump')),
    (df_raw['ACTION_TYPE'].str.contains('Dunk')),
]

choices_action = ['Pullup Jump Shot', 'Step Back Jump Shot', 'Driving Layup Shot', 'Layup', 'Other Jump Shot', 'Dunk']

conditions_value = [
    (df_raw['SHOT_TYPE'] == '3PT Field Goal')
]

choices_value = [3]

df = df_raw\
    .assign(
        action_type_clean= np.select(conditions_action, choices_action, default='Other'),
        shot_value = np.select(conditions_value, choices_value, default = 2),
        shot_zone = lambda x: x['SHOT_ZONE_BASIC'].apply(clean_threes)
    )

# %%
df['shot_value'] == 2 & (df['shot_zone'] == "Corner Three" | df['shot_zone'] == "Above the Break 3")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda2/envs/ipykernel_py3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1788         try:
# -> 1789             result = op(x, y)
#    1790         except TypeError:
#
# ~/anaconda2/envs/ipykernel_py3/lib/python3.7/site-packages/pandas/core/ops.py in ror_(left, right)
#     190 def ror_(left, right):
# --> 191     return operator.or_(right, left)
#     192
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda2/envs/ipykernel_py3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1803                 try:
# -> 1804                     result = libops.scalar_binop(x, y, op)
#    1805                 except (TypeError, ValueError, AttributeError,
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_binop()
#
# ~/anaconda2/envs/ipykernel_py3/lib/python3.7/site-packages/pandas/core/ops.py in ror_(left, right)
#     190 def ror_(left, right):
# --> 191     return operator.or_(right, left)
#     192
#
# TypeError: unsupported operand type(s) for |: 'bool' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-294013075c6e> in <module>
# ----> 1 df['shot_value'] == 2 & (df['shot_zone'] == "Corner Three" | df['shot_zone'] == "Above the Break 3")
#
# ~/anaconda2/envs/ipykernel_py3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other)
#    1848         filler = (fill_int if is_self_int_dtype and is_other_int_dtype
#    1849                   else fill_bool)
# -> 1850         res_values = na_op(self.values, ovalues)
#    1851         unfilled = self._constructor(res_values,
#    1852                                      index=self.index, name=res_name)
#
# ~/anaconda2/envs/ipykernel_py3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1808                                     "with a scalar of type [{typ}]"
#    1809                                     .format(dtype=x.dtype,
# -> 1810                                             typ=type(y).__name__))
#    1811
#    1812         return result
#
# TypeError: cannot compare a dtyped [object] array with a scalar of type [bool]

# %%
df['shot_value'] == 2 & df['shot_zone'] == "Corner Three"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda2/envs/ipykernel_py3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1788         try:
# -> 1789             result = op(x, y)
#    1790         except TypeError:
#
# ~/anaconda2/envs/ipykernel_py3/lib/python3.7/site-packages/pandas/core/ops.py in rand_(left, right)
#     186 def rand_(left, right):
# --> 187     return operator.and_(right, left)
#     188
#
# TypeError: unsupported operand type(s) for &: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda2/envs/ipykernel_py3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1803                 try:
# -> 1804                     result = libops.scalar_binop(x, y, op)
#    1805                 except (TypeError, ValueError, AttributeError,
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_binop()
#
# ~/anaconda2/envs/ipykernel_py3/lib/python3.7/site-packages/pandas/core/ops.py in rand_(left, right)
#     186 def rand_(left, right):
# --> 187     return operator.and_(right, left)
#     188
#
# TypeError: unsupported operand type(s) for &: 'bool' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-ea59ceca44c6> in <module>
# ----> 1 df['shot_value'] == 2 & df['shot_zone'] == "Corner Three"
#
# ~/anaconda2/envs/ipykernel_py3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other)
#    1848         filler = (fill_int if is_self_int_dtype and is_other_int_dtype
#    1849                   else fill_bool)
# -> 1850         res_values = na_op(self.values, ovalues)
#    1851         unfilled = self._constructor(res_values,
#    1852                                      index=self.index, name=res_name)
#
# ~/anaconda2/envs/ipykernel_py3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1808                                     "with a scalar of type [{typ}]"
#    1809                                     .format(dtype=x.dtype,
# -> 1810                                             typ=type(y).__name__))
#    1811
#    1812         return result
#
# TypeError: cannot compare a dtyped [object] array with a scalar of type [bool]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-beb4b2c7bad8> in <module>
#       1 thing = df['shot_value'] == 2
#       2 thing2 = df['shot_zone'] == "Corner Three"
# ----> 3 thing.bool + thing2.bool
#
# TypeError: unsupported operand type(s) for +: 'method' and 'method'
